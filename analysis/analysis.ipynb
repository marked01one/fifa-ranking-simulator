# %% [markdown]
# # FIFA Rankings - Default Dataset Analysis

# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_df = pd.read_csv("fifa_ranking-2022-12-22.csv")

# %%
main_df.head()
# Out:
#    rank    country_full country_abrv  total_points  previous_points  \
# 0    74      Madagascar          MAD          18.0              0.0
# 1    52           Qatar          QAT          27.0              0.0
# 2    51         Senegal          SEN          27.0              0.0
# 3    50     El Salvador          SLV          28.0              0.0
# 4    49  Korea Republic          KOR          28.0              0.0
#
#    rank_change confederation   rank_date
# 0            0           CAF  1992-12-31
# 1            0           AFC  1992-12-31
# 2            0           CAF  1992-12-31
# 3            0      CONCACAF  1992-12-31
# 4            0           AFC  1992-12-31

# %%
main_df[main_df['country_abrv'] == 'VIE']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 242     132      Vietnam          VIE          5.00             0.00
# 374     133      Vietnam          VIE          5.00             5.00
# 507     133      Vietnam          VIE          5.00             5.00
# 679     131      Vietnam          VIE          5.00             5.00
# 829     135      Vietnam          VIE          5.00             5.00
# ...     ...          ...          ...           ...              ...
# 63110    96      Vietnam          VIE       1215.38          1218.55
# 63313    97      Vietnam          VIE       1218.84          1215.38
# 63527    97      Vietnam          VIE       1218.84          1218.84
# 63741    96      Vietnam          VIE       1226.65          1218.84
# 63949    96      Vietnam          VIE       1228.63          1226.65
#
#        rank_change confederation   rank_date
# 242              0           AFC  1993-08-08
# 374              1           AFC  1993-09-23
# ...

# %%
afc_df = main_df[main_df['confederation'] == 'AFC'][main_df['rank_date'] == '2022-12-22'].sort_values(by=['total_points'], ascending=False).reset_index().drop(['index'], axis=1)
afc_df
# Out:
# C:\Users\Tran Minh Khoi\AppData\Local\Temp\ipykernel_14800\3203691804.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   afc_df = main_df[main_df['confederation'] == 'AFC'][main_df['rank_date'] == '2022-12-22'].sort_values(by=['total_points'], ascending=False).reset_index().drop(['index'], axis=1)
#     rank          country_full country_abrv  total_points  previous_points  \
# 0     20                 Japan          JPN       1593.08          1559.54
# 1     24               IR Iran          IRN       1551.73          1564.61
# 2     25        Korea Republic          KOR       1539.49          1530.30
# 3     27             Australia          AUS       1533.97          1488.72
# 4     49          Saudi Arabia          KSA       1438.13          1437.78
# 5     60                 Qatar          QAT       1393.56          1439.89
# 6     68                  Iraq          IRQ       1342.39          1343.01
# ...

# %%
afc_df.to_json(
  'sample_afc.json',
  orient='table',
  index=False,
  indent=2
)
